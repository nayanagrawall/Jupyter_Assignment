# %% [markdown]
# <a href="https://colab.research.google.com/github/nayanagrawall/Python-Codes/blob/main/fasttext_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199770 sha256=12c61a49c1c95b7d691b9506e8ea615573cfdd0d0be3fc732a92cb8c5a73da82
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# ...

# %%
import fasttext

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3b3a756-263b-4e31-a082-7558dc012c0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3b3a756-263b-4e31-a082-7558dc012c0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

df = pd.read_csv(io.BytesIO(uploaded['ecommerce_dataset.csv']))

# %%
df.head()
# Out:
#    Household  \
# 0  Household
# 1  Household
# 2  Household
# 3  Household
# 4  Household
#
# ...

# %%
print(df.shape)
# Out:
# (50424, 2)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50424, step=1)

# %%
print(df.columns)
# Out:
# Index(['Household', 'Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and
# ...

# %%
df.rename(columns={
    'Household':'category',
    'Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room.':'description'},
          inplace=True)

# %%
df.head()
# Out:
#     category                                        description
# 0  Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 1  Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 2  Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 3  Household  Incredible Gifts India Wooden Happy Birthday U...
# 4  Household  Pitaara Box Romantic Venice Canvas Painting 6m...

# %%
df.category.value_counts()
# Out:
# Household                 19312
# Books                     11820
# Electronics               10621
# Clothing & Accessories     8671
# Name: category, dtype: int64

# %%
df.category.replace("Clothing & Accessories","Clothing_Accessories", inplace=True)
df.category.value_counts()
# Out:
# Household               19312
# Books                   11820
# Electronics             10621
# Clothing_Accessories     8671
# Name: category, dtype: int64

# %%
df['category'] = "__label__" + df['category'].astype(str)
df.head()
# Out:
#              category                                        description
# 0  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 1  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 2  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 3  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
# 4  __label__Household  Pitaara Box Romantic Venice Canvas Painting 6m...

# %%
df['category_description'] = df['category'] + " " + df['description']
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 1  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 2  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 3  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
# 4  __label__Household  Pitaara Box Romantic Venice Canvas Painting 6m...
#
#                                 category_description
# 0  __label__Household SAF 'Floral' Framed Paintin...
# 1  __label__Household SAF 'UV Textured Modern Art...
# 2  __label__Household SAF Flower Print Framed Pai...
# 3  __label__Household Incredible Gifts India Wood...
# 4  __label__Household Pitaara Box Romantic Venice...

# %%
import re

def preprocess(text):
  text = re.sub(r'[^\w\s\']', ' ', text)
  text = re.sub(r' +', ' ', text)
  return text.strip().lower()

# %%
preprocess("  VIKI's  |  Bookcase/Bookshelf  (3-Shelf/Shelve, White)  | ? . hi")
# Out:
# "viki's bookcase bookshelf 3 shelf shelve white hi"

# %%
type(df['category_description'][0])
# Out:
# str

# %%
df['category_description'] = df['category_description'].map(preprocess)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c5ebda73f471> in <cell line: 1>()
# ----> 1 df['category_description'] = df['category_description'].map(preprocess)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4537         dtype: object
#    4538         """
# -> 4539         new_values = self._map_values(arg, na_action=na_action)
#    4540         return self._constructor(new_values, index=self.index).__finalize__(
#    4541             self, method="map"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     888
#     889         # mapper is a function
# --> 890         new_values = map_f(values, mapper)
#     891
#     892         return new_values
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (50423, 3)

# %%
df['category_description'] = df['category_description'].map(preprocess)

# %%
df.head()
# Out:
#              category                                        description  \
# 0  __label__Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 1  __label__Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 2  __label__Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 3  __label__Household  Incredible Gifts India Wooden Happy Birthday U...
# 4  __label__Household  Pitaara Box Romantic Venice Canvas Painting 6m...
#
#                                 category_description
# 0  __label__household saf 'floral' framed paintin...
# 1  __label__household saf 'uv textured modern art...
# 2  __label__household saf flower print framed pai...
# 3  __label__household incredible gifts india wood...
# 4  __label__household pitaara box romantic venice...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)

# %%
train.shape, test.shape
# Out:
# ((40338, 3), (10085, 3))

# %%
train.head()
# Out:
#                    category  \
# 26066        __label__Books
# 49763  __label__Electronics
# 41391  __label__Electronics
# 5190     __label__Household
# 30352        __label__Books
#
#                                              description  \
# 26066  Blockchain Revolution Review What a spectacula...
# 49763  JioPhone (Black)-Security Deposit Colour:Black...
# 41391  WD My Passport 1TB Portable External Hard Driv...
# 5190   AJANTA ROYAL Individual Synthetic Polymer Wood...
# 30352  Becoming Review An inspirational memoir that a...
#
#                                     category_description
# 26066  __label__books blockchain revolution review wh...
# 49763  __label__electronics jiophone black security d...
# 41391  __label__electronics wd my passport 1tb portab...
# 5190   __label__household ajanta royal individual syn...
# 30352  __label__books becoming review an inspirationa...

# %%
train.to_csv('ecommerce.train', columns=['category_description'], index=False, header=False)
test.to_csv('ecommerce.test', columns=['category_description'], index=False, header=False)

# %%
import fasttext

model = fasttext.train_supervised(input="ecommerce.train")
model.test('ecommerce.test')
# Out:
# (10085, 0.9697570649479424, 0.9697570649479424)

# %%
test.head()
# Out:
#                             category  \
# 21100                 __label__Books
# 39583  __label__Clothing_Accessories
# 15204             __label__Household
# 1869              __label__Household
# 34995  __label__Clothing_Accessories
#
#                                              description  \
# 21100  Software Architecture in Practice (Sei Series ...
# 39583  Matelco Beige Women's Woollen Buttoned v-Neck ...
# 15204  Homwell 2 Pole - 3 Layer Jumbo Multifunction P...
# 1869   Mahima Handicraft Sheesham Wooden Dining Table...
# 34995  CREATURE Men's Cotton Calf Length Casual Socks...
#
#                                     category_description
# 21100  __label__books software architecture in practi...
# 39583  __label__clothing_accessories matelco beige wo...
# 15204  __label__household homwell 2 pole 3 layer jumb...
# 1869   __label__household mahima handicraft sheesham ...
# 34995  __label__clothing_accessories creature men's c...

# %%
test['category'][17743]
# Out:
# '__label__Household'

# %%
model.predict('Software Architecture in Practice (Sei Series in Software Engineering) About the Author Len Bass is a Senior Principal Researcher at National ICT Australia Ltd (NICTA). He joined NICTA in 2011 after twenty-five years at the Software Engineering Institute (SEI) at Carnegie Mellon University. He is the coauthor of two award-winning books in software architecture, including Documenting Software Architectures: Views and Beyond, Second Edition (Addison-Wesley, 2011), as well as several other books and numerous papers in computer science and software engineering on a wide range of topics. Len has almost fifty years’ experience in software development and research in multiple domains, such as scientific analysis systems, embedded systems, and information systems.Paul Clements is the Vice President of Customer Success at BigLever Software, Inc., where he works to spread the adoption of systems and software product line engineering. \xa0Prior to this position, he was Senior Member of the Technical Staff at the SEI, where, for 17 years, he lead or co-lead projects in software product line engineering and software architecture documentation and analysis. Other books Paul has coauthored include Documenting Software Architectures: Views and Beyond, Second Edition (Addison-Wesley, 2011) and Evaluating Software Architectures: \xa0Methods and Case Studies, (Addison-Wesley, 2002), and Software Product Lines: Practices and Patterns (Addison-Wesley, 2002). \xa0In addition, he has also published dozens of papers in software engineering reflecting his long-standing interest in the design and specification of challenging software systems. Paul was a founding member of the IFIP WG2.10 Working Group on Software Architecture.Rick Kazman is a professor at the University of Hawaii and a Visiting Scientist (and former Senior Member of the Technical Staff) at the SEI. He is a coauthor of Evaluating Software Architectures: Methods and Case Studies, (Addison-Wesley, 2002). Rick’s primary research interests are software architecture, design and analysis tools, software visualization, and software engineering economics. He is also interested in human-computer interaction and information retrieval. Rick was one of the creators of several highly influential methods and tools for architecture analysis, including the SAAM (Software Architecture Analysis Method), the ATAM (Architecture Tradeoff Analysis Method), the CBAM (Cost-Benefit Analysis Method), and the Dali architecture reverse engineering tool')
# Out:
# (('__label__books',), array([0.97838575]))

# %%
model.predict('think and grow rich')
# Out:
# (('__label__books',), array([1.00000858]))

# %%
model.predict('Astrophysics for the People in Hurry')
# Out:
# (('__label__books',), array([0.99820453]))

# %%
model.predict('Jaguar body deoderant')
# Out:
# (('__label__books',), array([0.98318672]))

# %%
model.predict('Principles of Mass Transfer and Separation Processes About the Author BINAY K. DUTTA, Ph.D. (IIT Kharagpur), is Professor in the Chemical Engineering Department of Universiti Teknologi Petronas, Malaysia. He has over thirty-five years of research and teaching experience in chemical engineering. He taught in Regional Engineering College (now NIT), Durgapur, University of Calcutta and in University of Alberta, Canada, besides working as Visiting Scientist in NIST (Boulder, Colorado), Stevens Institute of Technology (New Jersey) and NRMRL of US EPA (Cincinnati, Ohio). He was the Head of Department of Chemical Engineering (1994-1995) and the Director of Academic Staff College (2000-2005) of the University of Calcutta. Professor Dutta has published extensively in international journals in several areas including transport processes, membrane separation, reaction engineering, environmental engineering, and mathematical modelling. He also holds several patents, and has authored Heat Transfer - Principles and Applications (Prentice-Hall of India, 2001). He is a member of a number of professional institutions. Professor Dutta was the President of the Indian Institute of Chemical Engineers in the year 2005.')
# Out:
# (('__label__books',), array([0.98955238]))

# %%
model.predict('Oleanna OHS-17 Chome Finish Overhead Shower with Shower Arm and Wall Flange (Shower) This Oleanna OHS-17 Overhead Shower head has an innovative design and varied features that makes it easier to use. The shower head is made of fine high-end ABS and Brass Arm, which ensures its longevity and extends maximum durability that serves you for long years. It also has numerous perforations, which ensure unhinged flow of water. It is easy to install and requires minimum maintenance. It has round shape single flow system with rub-it cleaning mechanism that helps it in self-cleaning, thus causing less build-up.')
# Out:
# (('__label__household',), array([0.7305159]))

# %%
model.get_nearest_neighbors('sony')
# Out:
# [(0.9993616342544556, 'existential'),
#  (0.9993413090705872, 'pc2mobile'),
#  (0.9993383288383484, 'notifies'),
#  (0.9993382096290588, 'looping'),
#  (0.9993317127227783, 'omnidirectional'),
#  (0.9993222951889038, 'fogproof'),
#  (0.999320924282074, 'ghosting'),
#  (0.9993205666542053, 'workflow'),
#  (0.9993175864219666, 'grilles'),
#  (0.99930739402771, 'mgen2hn')]

# %%
model.get_nearest_neighbors('painting')
# Out:
# [(0.9986599087715149, '3litre'),
#  (0.9986599087715149, "kitchen's"),
#  (0.9986599087715149, 'bevy'),
#  (0.9986599087715149, "bowl's"),
#  (0.9986491203308105, 'bello'),
#  (0.9986475706100464, 'ce1041dsb2'),
#  (0.99864661693573, 'parting'),
#  (0.9986435770988464, '300degree'),
#  (0.9986394047737122, 'tbsp'),
#  (0.9986340403556824, '800ml')]
